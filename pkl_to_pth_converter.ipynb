# %%
# %load_ext autoreload
# %autoreload 2

# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 1)) (2.1.0+cu118)
# Requirement already satisfied: torchvision in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 2)) (0.16.0+cu118)
# Requirement already satisfied: tqdm in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: numpy in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 4)) (1.24.4)
# Requirement already satisfied: pandas in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 5)) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 6)) (3.7.3)
# Requirement already satisfied: datasets in c:\users\austin\anaconda3\envs\env\lib\site-packages (from -r requirements.txt (line 7)) (2.14.6)
# Requirement already satisfied: filelock in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: typing-extensions in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: sympy in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torch->-r requirements.txt (line 1)) (2023.10.0)
# Requirement already satisfied: requests in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torchvision->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from torchvision->-r requirements.txt (line 2)) (10.1.0)
# Requirement already satisfied: colorama in c:\users\austin\anaconda3\envs\env\lib\site-packages (from tqdm->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (0.70.15)
# Requirement already satisfied: aiohttp in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from datasets->-r requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 6)) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from requests->torchvision->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from requests->torchvision->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from requests->torchvision->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\austin\anaconda3\envs\env\lib\site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import torchvision
import torchvision.models as models
from torchvision import transforms
from datasets import load_dataset, concatenate_datasets

# %%
print(f"PyTorch version: {torch.__version__}")

# Check PyTorch has access to MPS (Metal Performance Shader, Apple's GPU architecture)
print(f"Is MPS (Metal Performance Shader) built? {torch.backends.mps.is_built()}")
print(f"Is MPS available? {torch.backends.mps.is_available()}")

# Check for CUDA support
print(f"Is CUDA available? {torch.cuda.is_available()}")

# Set the device
if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Using device: {device}")
# Out:
# PyTorch version: 2.1.0+cu118
# Is MPS (Metal Performance Shader) built? False
# Is MPS available? False
# Is CUDA available? True
# Using device: cuda

# %%
# pick which model to load
model_name = "densenet_cifar100" # either "resnet" or "vgg_cifar10" or "vgg_cifar100"

model_path = os.path.join("models", model_name)

# %%
from EarlyExitModel import EarlyExitModel
import pickle
import io

# This loads VGG architecture into program memory. Looks out of place but needs to be here. This will get fixed when we rewrite model saving and loading
torch.hub.load("chenyaofo/pytorch-cifar-models", "cifar100_vgg11_bn", pretrained=True)

# Need a custom unpickler to load the model onto the CPU since it was trained on a GPU and dumped, not saved
class CPU_Unpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == 'torch.storage' and name == '_load_from_bytes':
            return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
        else: return super().find_class(module, name)

def load_model(path):
    # Load the model (classifiers trained, but no gates)
    # Load the model onto the CPU
    f = open(os.path.join(model_path, path), "rb")
    model = CPU_Unpickler(f).load()

    # Set the device on the model and its submodules
    model.device = device    
    model = model.to(device)
    model.costs = model.compute_costs_per_exit_module()

    return model



alpha_list = [i / 100 for i in range(0, 101)]
for alpha in alpha_list:
    alpha_no_decimals = str(alpha).replace('.', '_')
    for path in [f"full_model_with_exit_gates_alpha_{alpha_no_decimals}", "final_classifier"]:
        print(path)
        try:
            model = load_model(path)
            print(f"Found model at path {path} to convert")
        except FileNotFoundError:
            print("file not found")
            continue
        model_name = f"{path}.pth"
        state_dict_path = os.path.join(model_path, model_name)

        torch.save(model.state_dict(), state_dict_path)
# Out:
# full_model_with_exit_gates_alpha_0_0
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_01
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_02
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_03
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_04
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_05
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_06
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_07
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_08
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_09
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_1
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_11
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_12
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_13
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_14
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_15
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_16
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_17
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_18
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_19
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_2
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_21
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_22
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_23
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_24
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_25
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_26
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_27
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_28
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_29
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_3
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_31
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_32
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_33
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_34
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_35
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_36
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_37
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_38
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_39
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_4
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_41
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_42
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_43
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_44
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_45
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_46
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_47
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_48
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_49
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_5
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_51
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_52
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_53
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_54
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_55
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_56
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_57
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_58
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_59
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_6
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_61
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_62
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_63
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_64
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_65
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_66
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_67
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_68
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_69
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_7
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_71
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_72
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_73
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_74
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_75
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_76
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_77
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_78
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_79
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_8
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_81
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_82
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_83
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_84
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_85
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_86
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_87
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_88
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_89
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_9
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_91
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_92
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_93
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_94
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_95
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_96
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_97
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_98
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_0_99
# file not found
# final_classifier
# file not found
# full_model_with_exit_gates_alpha_1_0
# file not found
# final_classifier
# file not found
# Using cache found in C:\Users\Austin/.cache\torch\hub\chenyaofo_pytorch-cifar-models_master
